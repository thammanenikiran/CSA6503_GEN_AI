# %%
from transformers import pipeline

generator=pipeline("text-generation",model="gpt2")

result=generator("Artificial Intelligence",max_length=40)

print(result[0]["generated_text"])
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# Artificial Intelligence
#
# This section contains information about the AI that is programmed to learn from the data and learn from those that learn.
#
# AI's are constantly improving and new information becomes available by the day. These can be found in the AI's. The information that can be learned is based on a number of factors. The key is understanding of what's going on in your organization, what you are doing, and what your goals are.
#
# The best way to understand the AI's is to go over its data and learn from it. This is where the AI's come in.
#
# To learn from data, you first have to understand what it is you're learning from. For example, you want to know what's expected of you this year. This is a good time to learn from the data. If you're doing a job that requires a lot of training and is not in the same league as other jobs, then you can learn from it. To learn from data, you have to understand what's expected of you.
#
# The AI's come in all shapes and sizes. They're trained on a number of different things. For example, you can see the performance of a person in a task or when they do something. You can also look at how
