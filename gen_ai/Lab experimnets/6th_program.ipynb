# %%
from openai import OpenAI

client = OpenAI(
    api_key="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"
)

prompt = input("Enter your prompt: ")

response = client.responses.create(
    model="gpt-5.5",
    input=prompt
)

print(response.output_text)
