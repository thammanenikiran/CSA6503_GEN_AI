# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6J-HQQTc6sve1-RDUBtHGDtV3OB0owgn_VgjyN31BzFlg")

prompt = input("Enter your prompt: ")

response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents=prompt
)

print("\nGenerated Response:\n")
print(response.text)
# Out:
# Enter your prompt: why python is most powerful language
#
# Generated Response:
#
# To understand why Python is considered one of the most powerful programming languages in the world today, it is important to understand that in computer science, "power" is not just about raw execution speed.
#
# Instead, Python’s power lies in its **developer productivity, versatility, and its dominant ecosystem.**
#
# Here is a detailed breakdown of why Python is considered so powerful:
#
# ---
#
# ### 1. The Undisputed King of AI and Machine Learning
# Python is the foundational language for the Artificial Intelligence (AI) revolution. If you are working with AI, Machine Learning (ML), Deep Learning, or Data Science, you are almost certainly using Python.
# * **The Tools:** Python hosts the world's most powerful AI libraries, including **TensorFlow, PyTorch, Keras, Scikit-Learn, and Hugging Face**.
# * **Why Python?** AI involves complex mathematics. Python’s simple syntax allows researchers and data scientists to focus on solving AI problems rather than fighting with complex language syntax.
#
# ### 2. "Batteries Included" (Massive Ecosystem)
# Python’s philosophy is "batteries included." This means it comes with a vast standard library, and has over 400,000 third-party packages available via PyPI (Python Package Index). Whatever you want to build—be it a web scraper, a game, a scientific simulator, or a web application—someone has already written a library for it.
# * **Web Development:** Django and Flask.
# * **Data Analysis:** Pandas and NumPy.
# * **Web Scraping:** Beautiful Soup and Scrapy.
#
# ### 3. Readability and Speed of Development
# Python’s syntax is clean, elegant, and closely resembles written English.
# * **Less Code:** A task that takes 20 lines of code in Java or C++ often takes only 5 lines in Python.
# * **Readability:** Python forces clean formatting (using indentation rather than brackets). This makes code highly readable, easy to maintain, and easy for teams to collaborate on.
# * **Time-to-Market:** Businesses love Python because they can build a working prototype (MVP) in a fraction of the time it would take in other languages.
#
# ### 4. It is a "Glue Language"
# Python is incredibly good at talking to other languages. While Python itself is slow compared to C or C++, **Python can wrap around C/C++ code**.
# * For example, the heavy mathematical computations in Python’s science libraries (like NumPy and TensorFlow) are actually written in C/C++ under the hood.
# * This gives you the best of both worlds: the ease of writing Python, with the execution speed of C.
#
# ### 5. High Versatility (The "Swiss Army Knife")
# Some languages are good for only one thing (e.g., JavaScript for web browsers, Swift for iOS). Python can do almost anything:
# * Web Development (Back-end)
# * Data Analysis & Visualization
# * Artificial Intelligence & Machine Learning
# * Task Automation & Scripting (DevOps)
# * Cybersecurity & Ethical Hacking
# * Scientific & Numeric Computing
#
# ### 6. Backed by Tech Giants and a Massive Community
# Python is not going away anytime soon. It is heavily backed by companies like **Google, Meta, and Microsoft** (which employs the creator of Python, Guido van Rossum).
# Because millions of developers use Python, it has one of the most active communities on Earth. If you run into an error, the solution is almost always a single Google search away.
#
# ---
#
# ### Who uses Python?
# * **Google:** Used for search algorithms and AI.
# * **Netflix:** Uses Python for its recommendation engine and security.
# * **NASA:** Uses Python for scientific data analysis.
# * **Instagram:** The backend of Instagram is built on Django (a Python framework).
# * **Spotify:** Uses Python for data analysis and back-end services.
#
# ### Is Python perfect? (The Nuance)
# While powerful, Python is not the "best" language for every single task:
# * **It is slow:** Because it is an interpreted language, it is much slower than C++ or Rust for CPU-heavy tasks.
# * **Weak in Mobile:** Python is rarely used for building iOS or Android apps.
# * **High Memory Consumption:** It is not ideal for memory-constrained environments (like embedded systems).
#
# ### Conclusion
# Python is the "most powerful" language because of **leverage**. It allows a single programmer to achieve in one afternoon what used to take a team of programmers a week to build. Its dominance in AI ensures that it will remain at the forefront of technology for decades to come.
